# %%
import numpy as np
import pandas as pd
from glob import glob
import xml.etree.ElementTree as xet


import cv2

# %%
import os

# %%
df = pd.read_csv('labels.csv')
df.head()
# Out:
#                                             filepath  xmin  xmax  ymin  ymax
# 0  ./Kaggle data set/google_images\0073797c-a755-...   140   339   210   260
# 1  ./Kaggle data set/google_images\00b42b2c-f193-...   184   292   572   648
# 2  ./Kaggle data set/google_images\018b52e6-e9a1-...   327   399   202   227
# 3  ./Kaggle data set/google_images\03273806-bb1e-...   185   374   290   339
# 4  ./Kaggle data set/google_images\0369b20e-b432-...   335   453   313   347

# %% [markdown]
# ### LABEL YOLO
# center_x, center_y, width, height

# %%
#PARSING
#path= './google_images/00b42b2c-f193-4863-b92c-0245cbc816da___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-Petrol-Review-Images-Black-Front-Angle.xml'
def parsing(path):
    

    parser = xet.parse(path).getroot()
    name = parser.find('filename').text
    filename = f'./google_images/{name}'
    print(name)

        #width and height
    parser_size = parser.find('size')
    width = int(parser_size.find('width').text)
    height= int(parser_size.find('height').text)
    #print(width,height)   
    return filename,width,height

df[['filename','width','height']] = df['filepath'].apply(parsing).apply(pd.Series)
# Out:
# 0073797c-a755-4972-b76b-8ef2b31d44ab___new_IMG_20160315_071740.jpg.jpeg
# 00b42b2c-f193-4863-b92c-0245cbc816da___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-Petrol-Review-Images-Black-Front-Angle.jpg
# 018b52e6-e9a1-42c2-8ce7-0617e8c8e021___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_sbtb02_auto1.JPG
# 03273806-bb1e-48da-8c8b-a0133a90197a___2014-Skoda-Yeti-Test-Drive.jpg.jpeg
# 0369b20e-b432-4409-90f9-2420877aa386___8151536c79159a1557421da5f27f9f0e.jpg.jpeg
# 07064c2c-2aa3-4419-91a4-92916de8e54c___mahindra-scorpio-old-car-500x500.jpg.jpeg
# 074d85b8-42ec-4d17-9b8e-9e51ae060243___hqdefault.jpg.jpeg
# 07aaab79-71ee-4ea3-a9e6-640191183947___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_1208484d1392541449-nissan-terrano-official-review-img_20140215_181708.jpg
# 07bd977e-d578-49a2-b345-7cee5a4db6bf___new_1031520d1356604430-skoda-rapid-joins-family-edit-sold-wp_000281.jpg.jpeg
# 07e787a7-6cc3-482c-9ce5-f0ce115b47f1___new_VW-Polo-GT-TSI-badges-on-the-boot-lid.jpg.jpeg
# ...

# %%
df.head()
# Out:
#                                             filepath  xmin  xmax  ymin  ymax  \
# 0  ./Kaggle data set/google_images\0073797c-a755-...   140   339   210   260
# 1  ./Kaggle data set/google_images\00b42b2c-f193-...   184   292   572   648
# 2  ./Kaggle data set/google_images\018b52e6-e9a1-...   327   399   202   227
# 3  ./Kaggle data set/google_images\03273806-bb1e-...   185   374   290   339
# 4  ./Kaggle data set/google_images\0369b20e-b432-...   335   453   313   347
#
#                                             filename  width  height
# 0  ./google_images/0073797c-a755-4972-b76b-8ef2b3...    500     335
# 1  ./google_images/00b42b2c-f193-4863-b92c-0245cb...   1280     853
# 2  ./google_images/018b52e6-e9a1-42c2-8ce7-0617e8...    660     280
# 3  ./google_images/03273806-bb1e-48da-8c8b-a0133a...    588     476
# 4  ./google_images/0369b20e-b432-4409-90f9-242087...    480     480

# %%
df['center_x']= (df['xmax']+df['xmin'])/(2*df['width'])
df['center_y']= (df['ymax']+df['ymin'])/(2*df['height'])
#bounding box
df['bb_width']= (df['xmax']-df['xmin'])/df['width']
df['bb_height']= (df['ymax']-df['ymin'])/df['height']

# %%
df.head()
# Out:
#                                             filepath  xmin  xmax  ymin  ymax  \
# 0  ./Kaggle data set/google_images\0073797c-a755-...   140   339   210   260
# 1  ./Kaggle data set/google_images\00b42b2c-f193-...   184   292   572   648
# 2  ./Kaggle data set/google_images\018b52e6-e9a1-...   327   399   202   227
# 3  ./Kaggle data set/google_images\03273806-bb1e-...   185   374   290   339
# 4  ./Kaggle data set/google_images\0369b20e-b432-...   335   453   313   347
#
#                                             filename  width  height  center_x  \
# 0  ./google_images/0073797c-a755-4972-b76b-8ef2b3...    500     335  0.479000
# 1  ./google_images/00b42b2c-f193-4863-b92c-0245cb...   1280     853  0.185938
# 2  ./google_images/018b52e6-e9a1-42c2-8ce7-0617e8...    660     280  0.550000
# 3  ./google_images/03273806-bb1e-48da-8c8b-a0133a...    588     476  0.475340
# 4  ./google_images/0369b20e-b432-4409-90f9-242087...    480     480  0.820833
#
#    center_y  bb_width  bb_height
# ...

# %%
#Split the data into train and test
df_train = df.iloc[:200]
df_test = df.iloc[200:]

# %%
from shutil import copy

# %%
train_folder = './data_images/train'
values = df_train[['filename','center_x','center_y','bb_width','bb_height']].values
for fname, x, y, w, h in values:
    image_name = os.path.split(fname)[-1]
    txt_name = os.path.splitext(image_name)[0]
    
    dst_image_path = os.path.join(train_folder, image_name)
    dst_label_file = os.path.join(train_folder,txt_name+'.txt')
    
    #copy each image into folder
    copy(fname, dst_image_path)
    
    
    #genrate .txt which has label info
    label_txt = f'0{x} {y} {w} {h}'
    with open(dst_label_file, mode='w')as f:
        f.write(label_txt)
        
        f.close()

# %%
test_folder = './data_images/test'
values = df_test[['filename','center_x','center_y','bb_width','bb_height']].values
for fname, x, y, w, h in values:
    image_name = os.path.split(fname)[-1]
    txt_name = os.path.splitext(image_name)[0]
    
    dst_image_path = os.path.join(test_folder, image_name)
    dst_label_file = os.path.join(test_folder,txt_name+'.txt')
    
    #copy each image into folder
    copy(fname, dst_image_path)
    
    
    #genrate .txt which has label info
    label_txt = f'0{x} {y} {w} {h}'
    with open(dst_label_file, mode='w')as f:
        f.write(label_txt)
        
        f.close()
