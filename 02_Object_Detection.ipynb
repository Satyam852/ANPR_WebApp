# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2

# %%
df = pd.read_csv('labels.csv')
df.head()
# Out:
#                                             filepath  xmin  xmax  ymin  ymax
# 0  ./Kaggle data set/google_images\0073797c-a755-...   140   339   210   260
# 1  ./Kaggle data set/google_images\00b42b2c-f193-...   184   292   572   648
# 2  ./Kaggle data set/google_images\018b52e6-e9a1-...   327   399   202   227
# 3  ./Kaggle data set/google_images\03273806-bb1e-...   185   374   290   339
# 4  ./Kaggle data set/google_images\0369b20e-b432-...   335   453   313   347

# %%
from xml.etree import ElementTree as xet

# %%
filename = df['filepath'][2]
filename
# Out:
# './Kaggle data set/google_images\\018b52e6-e9a1-42c2-8ce7-0617e8c8e021___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_sbtb02_auto1.xml'

# %%
def getFilename(filename):
    filename_image = xet.parse(filename).getroot().find('filename').text
    filepath_image= os.path.join('./Kaggle data set/google_images', filename_image)
    return filepath_image

# %%
getFilename(filename)
# Out:
# './Kaggle data set/google_images\\018b52e6-e9a1-42c2-8ce7-0617e8c8e021___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_sbtb02_auto1.JPG'

# %%
#NOW APPLY THE FUNCTION TO ALL
image_path=df['filepath'].apply(getFilename)
image_path
# Out:
# 0      ./Kaggle data set/google_images\0073797c-a755-...
# 1      ./Kaggle data set/google_images\00b42b2c-f193-...
# 2      ./Kaggle data set/google_images\018b52e6-e9a1-...
# 3      ./Kaggle data set/google_images\03273806-bb1e-...
# 4      ./Kaggle data set/google_images\0369b20e-b432-...
#                              ...
# 435    ./Kaggle data set/google_images\fc1f58f0-2f54-...
# 436    ./Kaggle data set/google_images\fcabfaf7-160a-...
# 437    ./Kaggle data set/google_images\fd0140cc-e887-...
# 438    ./Kaggle data set/google_images\fda5760a-c6ff-...
# 439    ./Kaggle data set/google_images\fe3c95e4-7bd4-...
# Name: filepath, Length: 440, dtype: object

# %% [markdown]
# # VERIFY IMAGE AND OUTPUT

# %%
file_path= image_path[2]
file_path
# Out:
# './Kaggle data set/google_images\\018b52e6-e9a1-42c2-8ce7-0617e8c8e021___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_sbtb02_auto1.JPG'

# %%
img =cv2.imread(file_path)


cv2.namedWindow('example',cv2.WINDOW_NORMAL)
cv2.imshow('example',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#140	339	210	260
#cv2.rectangle(img,(140,210),(339,260),(0,255,0),3) FOR PATH = 0

#335	453	313	347
#cv2.rectangle(img,(335,313),(453,347),(0,255,0),3) FOR PATH=4
#MAKE SURE TO CHNAGE THE PATH IN ABOVE CODE IF YOU WANT TO CHANGE THE IMAGE OF CAR

#327	399	202	227 FOR PATH = 2
cv2.rectangle(img,(327,202),(399,227),(0,255,0),3)
cv2.namedWindow('example',cv2.WINDOW_NORMAL)
cv2.imshow('example',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # DATA Preprocessing

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img,img_to_array

# %%
df.iloc[:,1:]
# Out:
#      xmin  xmax  ymin  ymax
# 0     140   339   210   260
# 1     184   292   572   648
# 2     327   399   202   227
# 3     185   374   290   339
# 4     335   453   313   347
# ..    ...   ...   ...   ...
# 435   179   352   235   274
# 436    57   600    82   187
# 437   150   370   131   189
# 438   468   547   287   349
# 439   312   670   431   535
#
# [440 rows x 4 columns]

# %%
#label these

# %%
labels= df.iloc[:,1:].values

# %%
len(image_path)
# Out:
# 440

# %%
ind=0
data=[]
output=[]
for ind in range(len(image_path)):

    image = image_path[ind]
    img_arr=cv2.imread(image)
    h,w,d=img_arr.shape
    #preprocessing
    load_image = load_img(image,target_size=(224,224))
    load_image_arr=img_to_array(load_image)
    norm_load_image_arr=load_image_arr/255.0#normalization
    #normalization
    xmin,xmax,ymin,ymax= labels[ind]
    nxmin,nxmax=xmin/w,xmax/w
    nymin,nymax=ymin/h,ymax/h
    label_norm=(nxmin,nxmax,nymin,nymax)#normalized output
    
    #-----------------------append
    data.append(norm_load_image_arr)
    output.append(label_norm)

# %%
label_norm
# Out:
# (0.32533889468196037,
#  0.6986444212721585,
#  0.4494264859228363,
#  0.5578727841501564)

# %%
load_image_arr
# Out:
# array([[[ 39.,  37.,  24.],
#         [ 41.,  39.,  26.],
#         [ 41.,  39.,  26.],
#         ...,
#         [127., 115.,  99.],
#         [132., 121., 103.],
#         [130., 119.,  99.]],
#
#        [[ 42.,  38.,  26.],
#         [ 40.,  36.,  24.],
#         [ 43.,  39.,  27.],
#         ...,
#         [130., 118., 102.],
#         [133., 122., 104.],
#         [135., 124., 104.]],
#
#        [[ 43.,  37.,  25.],
#         [ 43.,  37.,  25.],
#         [ 45.,  39.,  27.],
#         ...,
#         [134., 122., 106.],
#         [134., 123., 105.],
#         [137., 126., 106.]],
#
#        ...,
#
#        [[ 37.,  25.,  25.],
#         [110.,  94.,  79.],
#         [114.,  97.,  81.],
#         ...,
#         [102.,  86.,  73.],
#         [101.,  85.,  72.],
#         [ 75.,  59.,  44.]],
#
#        [[ 58.,  44.,  43.],
#         [ 94.,  82.,  70.],
#         [105.,  91.,  78.],
#         ...,
#         [ 55.,  45.,  43.],
#         [116., 107., 100.],
# ...

# %%
x=np.array(data,dtype=np.float32)
y=np.array(output,dtype=np.float32)

# %%
x.shape,y.shape
# Out:
# ((440, 224, 224, 3), (440, 4))

# %% [markdown]
# # training and testing

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((352, 224, 224, 3), (88, 224, 224, 3), (352, 4), (88, 4))

# %% [markdown]
# # Deep learning model

# %%
from tensorflow.keras.applications import MobileNetV2, InceptionV3, InceptionResNetV2
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.models import Model
import tensorflow as tf

# %%
inception_resnet= InceptionResNetV2(weights="imagenet",include_top=False,input_tensor=Input(shape=(224,224,3)))

inception_resnet.trainable=False
#---------------------------------------------------
headmodel= inception_resnet.output
headmodel= Flatten()(headmodel)
headmodel = Dense(500,activation="relu")(headmodel)
headmodel = Dense(250,activation="relu")(headmodel)
headmodel = Dense(4,activation='sigmoid')(headmodel)
# Out:
# WARNING:tensorflow:From C:\Users\satya\anaconda3\lib\site-packages\keras\src\backend\tensorflow\core.py:184: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...
# 219055592/219055592 ━━━━━━━━━━━━━━━━━━━━ 18s 0us/step

# %%
model= Model(inputs=inception_resnet.input,outputs=headmodel)

# %% [markdown]
# # Compile the model

# %%
model.compile(loss='mse',optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4))
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 111, 111, 32)      │             864 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 111, 111, 32)      │              96 │ conv2d[0][0]               │
# ...

# %% [markdown]
# # MODEL TRAINING

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
tfb= TensorBoard('object_detection')

# %%
history = model.fit(x=x_train,y=y_train,batch_size=10,epochs=100, validation_data=(x_test,y_test),callbacks=[tfb])
# Out:
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - loss: 0.1168 - val_loss: 0.0997
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 872ms/step - loss: 0.0892 - val_loss: 0.0865
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 866ms/step - loss: 0.0843 - val_loss: 0.0777
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 865ms/step - loss: 0.0747 - val_loss: 0.0783
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 869ms/step - loss: 0.0735 - val_loss: 0.0850
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 869ms/step - loss: 0.0758 - val_loss: 0.0824
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 863ms/step - loss: 0.0759 - val_loss: 0.0864
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 867ms/step - loss: 0.0747 - val_loss: 0.0755
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 862ms/step - loss: 0.0726 - val_loss: 0.0754
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 861ms/step - loss: 0.0729 - val_loss: 0.0783
# Epoch 11/100
# ...

# %%
# Ensure the directory exists
#os.makedirs('./ANPR/Models', exist_ok=True)

# Save the model in the native Keras format
model.save('./Models/object_detection.keras')
